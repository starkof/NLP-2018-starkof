# %%
import nltk

from nltk.stem.lancaster import LancasterStemmer
from nltk.stem import WordNetLemmatizer
import numpy as np
import pandas as pd
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn import metrics
from sklearn.metrics import accuracy_score, classification_report
import sys
import re

# %%
def read_data():
    question_data = pd.read_csv('questions_qa.txt', sep='\t', names=['questions'], index_col= None, header = 0,encoding =  "ISO-8859-1")
    #answers_data = pd.read_csv('answers_qa.txt', sep='\t', names=['answers'], index_col= None, header = 0,encoding = "ISO-8859-1")
        
    #After getting the data I combine them into 1 data frame to get questions and topics
    q_t_data = pd.concat([question_data,answers_data],axis=1)
    
    #I then return the questions and topics as a list
    return q_t_data.questions.values.tolist(), q_t_data.answers.values.tolist()

# %%
def stemming(questions):
    lancaster_stemmer = LancasterStemmer()
    n_questions = []
    for question in questions:
        n_questions.append(' '.join(lancaster_stemmer.stem(token)for token in nltk.word_tokenize(question)))
    return(n_questions)

# %%
def lemming(questions):
    wordnet_lemmatizer = WordNetLemmatizer()
    n_questions = []
    for question in questions:
        n_questions.append(' '.join(wordnet_lemmatizer.lemmatize(token)for token in nltk.word_tokenize(question)))
    return(n_questions)

# %%
def lr_train(questions,labels):

    #N-gram model that comes up with features or occurances of words
    
    count_vect = CountVectorizer(stop_words='english')
    tf_transform = TfidfTransformer()
    


    X_train_counts = count_vect.fit_transform(r for r in questions)
    
    # This is to scale down impact of tokens that occur very frequently and arent
    #very informative.
    #Term Frequency time Inverse Document Frequency
    
    X_train_tf = tf_transform.fit_transform(X_train_counts)
    
    #splitting data into test and training sets
    X_train, X_test, Y_train, Y_test =train_test_split(X_train_tf,labels, random_state = 35 , train_size =0.80, test_size =0.20)
 

    #MAKING THE MODEL
    lrn = LogisticRegression()
    model = lrn.fit(X_train, Y_train)
    #array.reshape(-1, 1)
    
    return lrn, tf_transform, count_vect, model, X_test, Y_test

# %%
def  lr_test(test_file,questions,labels):
    lrn,tf_transform, count_vect, model, X_test, Y_test = lr_train(questions,labels)
    predicted = model.predict(X_test)    
    print("The accuracy of the model is: " ,accuracy_score(Y_test, predicted))
    print("This is a more detailed report of the QA models performance: \n" ,classification_report(Y_test, predicted))
    return(predicted,"\n")

# %%
def LR(testfile):
    questions, answers = read_data()
    questions = stemming(questions)
    questions = lemming(questions)
    
    lr_test(testfile,questions, answers)

# %%
def results(predictL):

    results = open("results.txt", "w+")

    
    for label in predictL[0]:
        results.write(str(label)+"\n")

# %%
def main():
    script = sys.argv[0]
    file_name=sys.argv[1]
    LR("'test_sentences2.txt")

main()
# Out:
# The accuracy of the model is:  0.21604938271604937
# This is a more detailed report of the QA models performance:
#                                                                                                                precision    recall  f1-score   support
#
#                                     The first verifiable written documents appeared in the twelfth century.        0.00      0.00      0.00         1
#                                                                                                  1.6 million       0.00      0.00      0.00         1
#                                                                                     11-year-old Grace Bedell       0.00      0.00      0.00         1
#                                                                                                12th century.       0.00      0.00      0.00         1
#                                                                                    176,214 square kilometres       0.00      0.00      0.00         1
#                                                                                                    1817-1825       0.00      0.00      0.00         1
#                                                                                                         1820       0.00      0.00      0.00         1
#                                                                                                         1832       0.00      0.00      0.00         1
#                                                                                                         1846       0.00      0.00      0.00         1
#                                                                                                         1908       0.00      0.00      0.00         1
#                                                                                                         1952       0.00      0.00      0.00         1
#                                                                                                         1957       0.00      0.00      0.00         1
#                                                                                                    22 months       0.00      0.00      0.00         1
#                                                                                              3,300 years old       0.00      0.00      0.00         1
#                                                                                                      350,000       0.00      0.00      0.00         1
#                                                                                                     4 inches       0.00      0.00      0.00         1
#                                                                                                 4 to 6 years       0.00      0.00      0.00         1
#                                                                                                      5-15 cm       0.00      0.00      0.00         1
#                                                                                                            6       0.00      0.00      0.00         1
#                                                                                                     75 years       0.00      0.00      0.00         1
#                                      A fake biography based on real events that happened in Fillmore's life.       0.00      0.00      0.00         1
#                                                                                                       A holt       0.00      0.00      0.00         1
#                                              A stepmother transforming her children into swans for 900 years       0.00      0.00      0.00         1
#                                                                                              About 3 million       0.00      0.00      0.00         1
#                                                                                               Agnes Muirhead       0.00      0.00      0.00         1
#                                                                                                       Amedeo       0.00      0.00      0.00         1
#                                                                           An octopus learned to solve mazes.       0.00      0.00      0.00         1
#                                                                                              Around 1900 BCE       0.00      0.00      0.00         1
#                                           As a result, the two nations moved closer toward the War of 1812.        0.00      0.00      0.00         1
#                                                                                                Bahasa Melayu       0.00      0.00      0.00         1
#                                                                                           Because it was WW2       0.00      0.00      0.00         1
#                                                                                           Because of grazing       0.00      0.00      0.00         1
#                                              Because of the way they withdraw their heads into their shells.       0.00      0.00      0.00         1
#                                                                                                      Before.       0.00      0.00      0.00         1
#                                                                                 California State Park system       0.00      0.00      0.00         1
#                                                                                                      Celsius       0.00      0.00      0.00         1
#                                                                                                      Chinese       0.00      0.00      0.00         1
#                                                                                                     Chinese.       0.00      0.00      0.00         1
#                                                                                                Crash cymbals       0.00      0.00      0.00         1
#                   Cymbals are used in modern orchestras and many military, marching, concert and other bands       0.00      0.00      0.00         1
#                                                                                            December 15, 1852       0.00      0.00      0.00         1
#                                                                        Doctor of Civil Law degree (honorary)       0.00      0.00      0.00         1
#                                                                                         Doha Players Theatre       0.00      0.00      0.00         1
#                                                                                                    Dominance       0.00      0.00      0.00         1
#                                                                                      Every few years or more       0.00      0.00      0.00         1
#                                                                                                      Faraday       0.00      0.00      0.00         1
#                                                                                                       France       0.00      0.00      0.00         1
#                                                                                                    Fred Dent       0.00      0.00      0.00         1
#                                                                                                      Germany       0.00      0.00      0.00         1
#                                                                                                      Gourds.       0.00      0.00      0.00         1
#                                                                                                        Grant       0.00      0.00      0.00         1
#                                                                  His daughter Maria Hester Monroe Gouverneur       0.00      0.00      0.00         1
#                                                                                                      In 1905       0.00      0.00      0.00         1
#                                                      In 1990, Goh Chok Tong succeeded Lee as Prime Minister.       0.00      0.00      0.00         1
#                                                                                                 In Greenock.       0.00      0.00      0.00         1
#                                                              In Kyoto there was a vast swarm of butterflies.       0.00      0.00      0.00         1
#                                                                                              Irish Americans       0.00      0.00      0.00         1
# It was during the 20th century that a common, standardized national language became available to all Swedes.       0.00      0.00      0.00         1
#                                                                                         It was too expensive       0.00      0.00      0.00         1
#                                                                               It's between June and October.       0.00      0.00      0.00         1
#                                                                                   It's extremely long tongue       0.00      0.00      0.00         1
#                                        Korean is descended from Old Korean, Middle Korean and Modern Korean.       0.00      0.00      0.00         1
#                                                                                  Late Spring or Early Summer       0.00      0.00      0.00         1
#                                                                      Libya, Sudan, the Gaza Strip and Israel       0.00      0.00      0.00         1
#                                                                                           Logging and lumber       0.00      0.00      0.00         1
#                                                                                                       London       0.00      0.00      0.00         1
#                                                                                              Long guard hair       0.00      0.00      0.00         1
#                                                                                                       Malay        0.00      0.00      0.00         1
#       Males are considerably larger than females and weigh 37 to 90 kg compared to 28 to 60 kg for females.        0.00      0.00      0.00         1
#                                                                                                  Martinique        0.00      0.00      0.00         1
#                                                                                                   Melburnian       0.00      0.00      0.00         1
#                                                                     Montreal has two international airports.       0.00      0.00      0.00         1
#                                                                                         Much of the country.       0.00      0.00      0.00         1
#                                                                                                           No       0.00      0.00      0.00        13
#                                                                                                          No.       0.00      0.00      0.00         3
#                                                                                                         None       0.00      0.00      0.00         1
#                                                                                                       Norway       0.00      0.00      0.00         1
#                                                                                            Old English swan.       0.00      0.00      0.00         1
#                                                      Opening and closing holes in the body of the instrument       0.00      0.00      0.00         1
#                                        Orang Laut people lived around the coast, rivers and smaller islands.       0.00      0.00      0.00         1
#                                                                                                       Otters       0.00      0.00      0.00         1
#                                                                                               Paracryptodira       0.00      0.00      0.00         1
#                                                                                                        Paris       0.00      0.00      0.00         1
#                                                                                              Penguins' wings       0.00      0.00      0.00         1
#                                      Portuguese is the co-official language with Cantonese Chinese in Macau.       0.00      0.00      0.00         1
#                                                                                                       Qatar.       0.00      0.00      0.00         1
#                                                                           Roman Catholic, Protestant, Jewish       0.00      0.00      0.00         1
#                                                                                        San Carlos, Maldonado       0.00      0.00      0.00         1
#                                                                                           September 3, 1971.       0.00      0.00      0.00         1
#                                       Serbian, Czech, English, French, German, Hungarian, Italian, and Latin       0.00      0.00      0.00         1
#                                                                                                    Sometimes       0.00      0.00      0.00         1
#                                                                                           Staunton, Virginia       0.00      0.00      0.00         1
#                                                               Studio pianos are around 42 to 45 inches tall.       0.00      0.00      0.00         1
#                                                                                         Subject Object Verb.       0.00      0.00      0.00         1
#                                                                                      Switzerland and Austria       0.00      0.00      0.00         1
#                                                               Taipei 101 is a 101-floor landmark skyscraper.       0.00      0.00      0.00         1
#                                                                         The Chieftains and Loreena McKennitt       0.00      0.00      0.00         1
#                                                                                          The Mask and Mirror       0.00      0.00      0.00         1
#                                                                                       The Reichstag building       0.00      0.00      0.00         1
#                                                                                    The United States Embassy       0.00      0.00      0.00         1
#                                                                                   The White Nights Festival.       0.00      0.00      0.00         1
#                                                                         The capital of Indonesia is Jakarta.       0.00      0.00      0.00         1
#                                                                                       The center of a Cymbal       0.00      0.00      0.00         1
#  The combination of a clash cymbol being accompanied by a bass drum playing an identical part, played loudly       0.00      0.00      0.00         1
#           The dialect spoken in Jeju is in fact classified as a different language by some Korean linguists.       0.00      0.00      0.00         1
#                                                  The indonesian archipelago became an important trade region       0.00      0.00      0.00         1
#                               The lack of cases in Swedish is compensated by a wide variety of prepositions.       0.00      0.00      0.00         1
#                                                                                       The name "Coleoptera".       0.00      0.00      0.00         1
#                                                                          The octopus has four pairs of arms.       0.00      0.00      0.00         1
#                                               The slide down snowy slopes, apparently for sheer enjoyment.         0.00      0.00      0.00         1
#                  The two zoos in Berlin are the Zoologischer Garten Berlin and the Tierpark Friedrichsfelde.       0.00      0.00      0.00         1
#                                                                              Their hind feet and their tails       0.00      0.00      0.00         1
#                                                             There are around 300 recognized octopus species.       0.00      0.00      0.00         1
#                                                   There are seven verb paradigms or speech levels in Korean.       0.00      0.00      0.00         1
#                                                                                             They are heavier       0.00      0.00      0.00         1
#                                                                                         To deal with bullies       0.00      0.00      0.00         1
#                                                       Triassic, Ernst Haeckel, Kunstformen der Natur, Animal       0.00      0.00      0.00         1
#                                                                                          Tsinghua University       0.00      0.00      0.00         1
#                                                                                                          Two       0.00      0.00      0.00         1
#                                                                                       University of Virginia       0.00      0.00      0.00         1
#                                                                                                 Voltaic Pile       0.00      0.00      0.00         1
#                                                                Vowel harmony and an agglutinative morphology       0.00      0.00      0.00         1
#                                                                                Washington National Cathedral       0.00      0.00      0.00         1
#                                                                                            Westminster Abbey       0.00      0.00      0.00         1
#                                                                                Westmoreland County, Virginia       0.00      0.00      0.00         1
#         When a stream of air directed across a hole in the instrument creats a vibration of air at the hole.       0.00      0.00      0.00         1
#                                                                                                          Yes       0.19      0.68      0.30        56
#                                                         Yes, Montreal contains the largest church in Canada.       0.00      0.00      0.00         1
#                                             Yes, diglossia is a common feature in mainland China and Taiwan.       0.00      0.00      0.00         1
#                                                                                                         Yes.       0.00      0.00      0.00        14
#                                                                                                         Yolk       0.00      0.00      0.00         1
#                     a large hotel infrastructure and a world-class convention facility in the Moscone Center       0.00      0.00      0.00         1
#                                                                                    approximately 800 species       0.00      0.00      0.00         1
#                                                                                                   at least 3       0.00      0.00      0.00         1
#                                       being farmed for their meat, eggs, feathers, (particularly their down)       0.00      0.00      0.00         1
#                                                                                 by the length of their tails       0.00      0.00      0.00         1
#                                                                                                     circular       0.00      0.00      0.00         1
#                                                                                                clash cymbals       0.00      0.00      0.00         1
#                                                                                cougar, bobcat, Canadian lynx       0.00      0.00      0.00         1
#                                                                                                 damper pedal       0.00      0.00      0.00         1
#                                                                                           ecclesiastical law       0.00      0.00      0.00         1
#                                                                                                         fish       0.00      0.00      0.00         1
#                                                                                                from G3 to C8       0.00      0.00      0.00         1
#                                                                                                         holt       0.00      0.00      0.00         1
#                                                                                                        honey       0.00      0.00      0.00         1
#                                                                       in a log cabin in Summerhill, New York       0.00      0.00      0.00         1
#                                                                                                      mimicry       0.00      0.00      0.00         1
#                                                                            modern electromagnetic technology       0.00      0.00      0.00         1
#                                                                                                 modern times       0.00      0.00      0.00         1
#                                                          muddy confluence, "muddy estuary," and "muddy city"       0.00      0.00      0.00         1
#                                                                                                           no       0.00      0.00      0.00        11
#                                                                                                 observations       0.00      0.00      0.00         1
#                                                                                              on the shoulder       0.00      0.00      0.00         1
#                                                                        phographic plates being fully exposed       0.00      0.00      0.00         1
#                                                                                              prey-dependency       0.00      0.00      0.00         1
#                                                                                              relatively warm       0.00      0.00      0.00         1
#                                                                      savannas, grasslands, or open woodlands       0.00      0.00      0.00         1
#                                                          semi-arid grasslands of Ethiopia and northern Kenya       0.00      0.00      0.00         1
#                                                                                                          six       0.00      0.00      0.00         1
#                                                                                               slavery issues       0.00      0.00      0.00         1
#                                                                                       the "Roaring Twenties"       0.00      0.00      0.00         1
#                                                                                               the first cell       0.00      0.00      0.00         1
#                                                                        the head, the thorax, and the abdomen       0.00      0.00      0.00         1
#                                       the killing of several prey animals too numerous to eat at one sitting       0.00      0.00      0.00         1
#                                                            the only arable agricultural land is found there,       0.00      0.00      0.00         1
#                                                                                       they do not break down       0.00      0.00      0.00         1
#                                                                                           thousands of years       0.00      0.00      0.00         1
#                                                                                                 warrior king       0.00      0.00      0.00         1
#                                                         when penguins slide on their bellies across the snow       0.00      0.00      0.00         1
#                                                                                                          yes       0.26      0.52      0.34        62
#                                                                                                         yes.       0.00      0.00      0.00         1
#
#                                                                                                  avg / total       0.08      0.22      0.12       324
# C:\Users\study\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
